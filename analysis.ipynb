# %%
import mlflow
from mlflow.tracking import MlflowClient

import os, sys

import torch
import torch.nn.functional as F

HOME = os.environ["HOME"]
CARDIAC_COMA_REPO = f"{HOME}/01_repos/CardiacCOMA/"
import os; os.chdir(CARDIAC_COMA_REPO)

from config.load_config import load_yaml_config, to_dict

import ipywidgets as widgets
from ipywidgets import interact
from IPython.display import Image

import pandas as pd
import shlex
from subprocess import check_output

import pickle as pkl
import pytorch_lightning as pl

from argparse import Namespace
import matplotlib.pyplot as plt

#import surgeon_pytorch
#from surgeon_pytorch import Inspect, get_layers

import numpy as np
import pandas as pd
from IPython import embed
sys.path.insert(0, '..')

# import model.Model3D
# from utils.helpers import get_coma_args, get_lightning_module, get_datamodule
from copy import deepcopy
from pprint import pprint

from typing import List
from tqdm import tqdm

import pyvista as pv
from ipywidgets import interact, interactive, fixed, interact_manual
# Out:
# /apps/developers/compilers/anaconda/2019.10/1/default/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-aa3b0a7cca10> in <module>
#       4 import os, sys
#       5
# ----> 6 import torch
#       7 import torch.nn.functional as F
#       8
#
# ModuleNotFoundError: No module named 'torch'

# %%
from utils.mlflow_queries import \
    list_artifacts,\
    get_significant_loci,\
    get_metrics_cols, \
    get_params_cols, \
    get_runs_df, \
    get_good_runs,\
    summarize_loci_across_runs,\
    get_model_pretrained_weights

# %%
TRACKING_URI = f"file://{CARDIAC_COMA_REPO}/mlruns"
mlflow.set_tracking_uri(TRACKING_URI)
client = MlflowClient()

# %%
def experiment_selection_widget():
    
    '''
    Returns a selection widget for MLflow experiments.
    '''
    
    options = [exp.name for exp in mlflow.list_experiments()]

    experiment_w = widgets.Select(
      options=options,
      value="Cardiac - ED"
    )
    
    return experiment_w

# %%
exp_w = experiment_selection_widget()

@interact
def get_runs(exp_name=exp_w):
    try:  
        global runs_df
        exp_id = mlflow.get_experiment_by_name(exp_name).experiment_id
        runs_df = get_runs_df(exp_name=exp_name, only_finished=True)
        metrics, params    = get_metrics_cols(runs_df), get_params_cols(runs_df)  
        # display(runs_df.loc[:, [*metrics, *params]].drop("params.platform", axis=1).head(10))
    except:
        pass
# Out:
# interactive(children=(Select(description='exp_name', index=1, options=('Default', 'Cardiac - ED', 'Cardiac - E…

# %%
def change_col_names(exper_id, run_id, df):
    df.columns = [f"{exper_id}_{run_id[:5]}_{col}" for col in df.columns]
    return df

def path_to_z(row):
    run_id = (row.experiment_id, row.run_id)
    artifacts_dir = row.artifact_uri.replace("file://", "") 
    z_adj_path = f'''output/z_adj_{row.experiment_id}_{row.run_id}.tsv'''    
    z_adj_path = os.path.join(artifacts_dir, z_adj_path)    
    return (run_id, z_adj_path)

# %%
z_paths = runs_df.reset_index().apply(path_to_z, axis=1)
z_paths = dict(z_paths.values.tolist())

# %%
z_dfs = {}
for run_id, z_path in tqdm(z_paths.items()):
    try:
        z_dfs[run_id] = pd.read_csv(z_path, sep="\t").set_index("ID")
    except FileNotFoundError:
        # print(f"Latent vector file does not exist for {run_id}")
        pass
    
z_dfs_renamed = [change_col_names(expid, runid, z_df) for (expid, runid), z_df in z_dfs.items()]    
z_all_df = pd.concat(z_dfs_renamed, axis=1)
z_all_df.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 204/204 [00:15<00:00, 13.04it/s]
#          1_e6490_z000  1_e6490_z001  1_e6490_z002  1_e6490_z003  1_e6490_z004  \
# ID
# 2471198      0.754081      0.217631      0.892939      0.801908      0.398927
# 1746709     -0.985621     -0.575624     -2.010317     -1.195979     -1.948443
# 2008596     -1.323050     -2.476096     -1.314485     -1.831838     -2.217431
# 4917788      0.275106      0.853365      0.618360      1.108492      0.711543
# 1780889     -1.405695      0.349099     -0.181581     -0.567419     -0.055743
#
#          1_e6490_z005  1_e6490_z006  1_e6490_z007  1_e6490_z008  1_e6490_z009  \
# ID
# 2471198     -0.485893      0.287335     -0.977530      0.292033     -0.335887
# 1746709      2.083467      1.517243      1.628201     -0.734581     -0.537734
# 2008596      1.894083      0.395576      1.415595      0.808040      0.837866
# 4917788     -0.204171      0.523633     -0.321992      0.623396      0.096480
# 1780889      0.754549      0.506033      0.170072      0.176574      1.168651
#
#          ...  1_17629_z006  1_17629_z007  1_17629_z008  1_17629_z009  \
# ID       ...
# 2471198  ...      0.529536      0.301523     -0.036083     -0.444244
# 1746709  ...      1.484463      1.207427     -1.787333      1.504024
# 2008596  ...      2.471592     -0.454913      0.649513     -1.352151
# 4917788  ...      0.325998      0.760645     -0.456241      0.196630
# 1780889  ...     -0.076131      0.479961     -1.147999      1.031148
#
#          1_17629_z010  1_17629_z011  1_17629_z012  1_17629_z013  1_17629_z014  \
# ID
# 2471198     -0.190534     -0.052853     -0.020239      0.952413      0.081639
# 1746709     -1.848678     -1.583979     -1.340997     -0.229178      1.150588
# 2008596     -0.884789     -0.391621      0.205825      1.250260     -0.620919
# 4917788     -0.403658     -0.536270     -0.052783      0.592991      0.395652
# 1780889     -0.868456     -1.414637     -0.752959      0.144984      0.524764
#
#          1_17629_z015
# ID
# 2471198     -0.146265
# 1746709     -1.269248
# 2008596      0.428527
# 4917788     -0.476883
# 1780889     -0.484389
#
# [5 rows x 576 columns]

# %% [markdown]
# # Genomic PCA

# %%
GENOMIC_PC_FILE = f'''{os.environ["HOME"]}/01_repos/GWAS_pipeline/data/transforms/GenomicPCA/pcs.txt'''

# %%
genomic_pca_df = pd.read_csv(GENOMIC_PC_FILE, sep="\t")
genomic_pca_df = genomic_pca_df.set_index("IID").drop("FID", axis=1)

# %%
genomic_pca_df
# Out:
#               PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# IID
# 1000336  0.009439  0.020864  0.005781 -0.018697 -0.000904  0.022974  0.005486
# 1000363  0.023638  0.018311  0.044009  0.002280 -0.030949 -0.025851  0.001375
# 1000380  0.035396  0.011719 -0.008578 -0.004962 -0.003340 -0.004983  0.016331
# 1000407  0.011639  0.026969 -0.050002  0.034824 -0.005536  0.012261 -0.055735
# 1000739  0.037332 -0.036103 -0.013930  0.011619 -0.000667  0.006000 -0.008560
# ...           ...       ...       ...       ...       ...       ...       ...
# 4999331  0.017444  0.002880 -0.040644 -0.010896  0.000275 -0.018865  0.004250
# 4999373  0.027891 -0.017130  0.002323  0.015145 -0.003229 -0.002498 -0.024503
# 4999543  0.001270 -0.009798 -0.007581 -0.022535 -0.023158  0.015697 -0.016623
# 4999719  0.025469  0.021132 -0.007243 -0.004814  0.014104  0.029959  0.013883
# 4999878  0.023852 -0.045589 -0.011327 -0.008369 -0.003902 -0.008220  0.006020
#
#               PC8       PC9      PC10
# IID
# 1000336 -0.013221 -0.017238 -0.016062
# 1000363 -0.019926 -0.002900 -0.027202
# 1000380 -0.032201 -0.022172  0.010668
# 1000407  0.021770 -0.004737  0.015074
# 1000739 -0.009928 -0.012613  0.000171
# ...           ...       ...       ...
# 4999331  0.039717  0.030166 -0.005031
# 4999373  0.030038 -0.016532  0.023511
# 4999543  0.009144  0.009319 -0.005967
# 4999719 -0.051551 -0.005785  0.004260
# 4999878  0.020802 -0.018473 -0.016061
#
# [31668 rows x 10 columns]

# %% [markdown]
# ### Correlation genomic PCs vs. latent variables

# %%
import statsmodels.api as sm

# %%
from scipy.stats import spearmanr

# %%
genomic_pca_df.loc[z_all_df.index]
# Out:
#               PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# ID
# 2471198 -0.051873  0.001545 -0.009844 -0.012530 -0.020395  0.020359  0.019912
# 1746709 -0.055044 -0.038579 -0.009757  0.008254 -0.011455 -0.000482  0.002033
# 2008596  0.027035 -0.005019 -0.005780  0.018832  0.021634 -0.029754  0.019613
# 4917788  0.018510  0.000287 -0.010316 -0.003669 -0.007625  0.009048 -0.014913
# 1780889  0.031780 -0.005839 -0.007639 -0.027031 -0.003665 -0.023096  0.016856
# ...           ...       ...       ...       ...       ...       ...       ...
# 4485380  0.012538  0.030180 -0.012806  0.004318 -0.002375 -0.011069  0.001156
# 3878790  0.010731  0.023344  0.012479 -0.022059  0.004118  0.018627 -0.050603
# 1703522 -0.042462  0.010479 -0.012252  0.049719  0.033033 -0.012664 -0.045234
# 2034360 -0.025799  0.035614 -0.021480 -0.005922 -0.010112 -0.026073 -0.039966
# 4424098  0.009815  0.020072  0.017277 -0.007925  0.014231 -0.002408 -0.007758
#
#               PC8       PC9      PC10
# ID
# 2471198 -0.002931 -0.001709 -0.020747
# 1746709 -0.034306  0.013822  0.023042
# 2008596 -0.003437 -0.008844 -0.031998
# 4917788  0.028892 -0.005289  0.026850
# 1780889 -0.024841 -0.013299 -0.018932
# ...           ...       ...       ...
# 4485380  0.025411  0.011179 -0.005765
# 3878790  0.019430 -0.013923  0.018948
# 1703522 -0.021413 -0.002971 -0.019009
# 2034360 -0.038286 -0.011845 -0.009643
# 4424098 -0.013620  0.009423 -0.006178
#
# [31620 rows x 10 columns]

# %%
spearman_coef, spearman_pvalue = spearmanr(a=z_all_df, b=genomic_pca_df.loc[z_all_df.index])

# %%
# pd.DataFrame(spearman_coef)
np.log10(pd.DataFrame(spearman_pvalue[:-10,-10:])).describe()
# Out:
#                 0           1           2           3           4           5  \
# count  576.000000  576.000000  576.000000  576.000000  576.000000  576.000000
# mean    -0.964088   -0.390680   -0.875388   -1.842624   -0.485954   -0.235492
# std      1.379551    0.502829    0.724153    1.073164    0.301226    0.215412
# min     -8.726355   -4.200970   -3.708875   -5.396731   -1.739564   -1.792114
# 25%     -1.181492   -0.452812   -1.233469   -2.557068   -0.627332   -0.309444
# 50%     -0.408849   -0.223124   -0.682486   -1.823582   -0.455533   -0.170018
# 75%     -0.127852   -0.107934   -0.328792   -1.016941   -0.280242   -0.086728
# max     -0.001764   -0.000703   -0.000512   -0.001768   -0.000203   -0.001357
#
#                 6           7           8           9
# count  576.000000  576.000000  576.000000  576.000000
# mean    -0.418303   -0.869153   -0.701453   -0.431343
# std      0.285657    0.441398    0.472094    0.532030
# min     -1.972040   -2.073406   -2.747475   -2.766425
# 25%     -0.564718   -1.209094   -0.957526   -0.584666
# 50%     -0.369654   -0.986020   -0.677228   -0.218208
# 75%     -0.210622   -0.469428   -0.343121   -0.081460
# max     -0.002743   -0.002909   -0.001238   -0.000038

# %%
sm.regression.linear_model.OLS()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 sm.regression.linear_model.OLS()
#
# TypeError: __init__() missing 1 required positional argument: 'endog'

# %% [markdown]
# ### Correlation genomic PCs vs. traditional cardiac indices

# %%
timeframe = "1".zfill(3) # 001 --> end-diastole
datafolder = "data/cardio/cardiac_indices"

df = pd.concat([
    pd.read_csv(f"{datafolder}/G{i}/LVRV_time{timeframe}.csv", index_col="case_id") 
    for i in range(1,5)
])

df.index = df.index.astype(str)

df.head()

# %%
sph_df = pd.read_csv("data/cardio/sphericity.csv").set_index("id")
sph_df.index = sph_df.index.astype(str)

# %%
cardiac_indices_df = df.merge(sph_df, left_index=True, right_index=True)
